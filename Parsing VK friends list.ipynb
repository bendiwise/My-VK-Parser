# %%
from vkparser import MyVKParser
from myplots import barplot_from_list

# %% [markdown]
# Создадим объект типа MyVKParser

# %%
login = '+79*********'
password = '*********'

parser = MyVKParser(login, password)

# %% [markdown]
# Получим списки по полу, возрасту и универам пользователя по умолчанию (владельца указанного логина).

# %%
stats = parser.get_friends_stats()

# %%
stats['univer'][:5]
# Out:
# ['МГУ',
#  'РГУ нефти и газа (НИУ) им. И. М. Губкина',
#  'РГСУ',
#  'НИТУ МИСиС',
#  'МГУ']

# %% [markdown]
# ### ВУЗы

# %%
barplot_from_list(stats['univer'])

# %% [markdown]
# ### Пол

# %%
barplot_from_list(stats['gender'])

# %% [markdown]
# ### Возраст

# %%
barplot_from_list(stats['age'])

# %% [markdown]
# ## По другому пользователю

# %% [markdown]
# Получим полную инфу по моим друзьям.

# %%
my_friends_info = parser.get_friends_info()

# %% [markdown]
# Найдем там айдишник кого-нибудь из друзей.

# %%
user_id = parser.parse_ids(my_friends_info)['Porto Moris']

# %% [markdown]
# Посмотрим стату по его друзьям.

# %%
stats = parser.get_friends_stats(user_id=user_id)

# %% [markdown]
# ### ВУЗы

# %%
barplot_from_list(stats['univer'])

# %% [markdown]
# ### Пол

# %%
barplot_from_list(stats['gender'])

# %% [markdown]
# ### Возраст

# %%
barplot_from_list(stats['age'])
